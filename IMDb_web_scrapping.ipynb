# %%
#import libraries
import pandas as pd

# %%
# read the data
filepath = r"D:\Documentos\University of Utah\Spring 2022\IS 6496 - MSBA Capstone Course\Crimson Project\IMDb\title.basics.tsv\data.tsv"
df_movies = pd.read_csv(filepath, encoding = "utf-8", sep="\t")  # IMDb dataset
# Out:
# C:\Users\ander\AppData\Local\Temp\ipykernel_91980\13035661.py:3: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movies = pd.read_csv(filepath, encoding = "utf-8", sep="\t")  # IMDb dataset

# %%
# overview dataframe
df_movies
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9038279  tt9916848  tvEpisode              Episode #3.17
# 9038280  tt9916850  tvEpisode              Episode #3.19
# 9038281  tt9916852  tvEpisode              Episode #3.20
# 9038282  tt9916856      short                   The Wind
# 9038283  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...

# %%
# remove "\N" from starYear column
df_movies = df_movies.loc[df_movies["startYear"].isin(["\\N"]) == False,]

# %%
# change the dtype of startYear from str to numeric
df_movies["startYear"] = pd.to_numeric(df_movies["startYear"])

# %%
#filters
titleType = df_movies["titleType"]=="movie"
startYear = df_movies["startYear"]>2015
# originalTitle = df_movies["originalTitle"].str.contains('Top Gun')

#apply the filter to resize data set.
df_movies = df_movies.loc[titleType & startYear,]

# %%
startYear = df_movies["startYear"]==2022

df_movies.loc[startYear,]
# Out:
#             tconst titleType                                  primaryTitle  \
# 117734   tt0120589     movie                          A Dangerous Practice
# 254456   tt0265705     movie                                      Saurians
# 312869   tt0326716     movie                                       5-25-77
# 384244   tt0400871     movie                                      Take Out
# 409250   tt0426522     movie                                 Making Angels
# ...            ...       ...                                           ...
# 9027268  tt9893158     movie                                      Clowning
# 9027642  tt9894000     movie                 Twice As Strong: Made of Fire
# 9030150  tt9899344     movie  GodHead: In a fiction, in a dream of passion
# 9032439  tt9904252     movie             Nice & Naughty, A Christmas Story
# 9032617  tt9904648     movie                                  The Contrast
#
# ...

# %%
import boxofficemojo as bom

bom = bom.BoxOfficeMojo()

print (bom.get_movie_stats_by_name('black panther'))
